# %% [markdown]
# #    第6讲 线性回归模型与诊断

# %%
##数据说明：本数据是一份汽车贷款违约数据
##名称	中文含义
#id	id
#Acc	是否开卡(1=已开通)
#avg_exp	月均信用卡支出（元）
#avg_exp_ln	月均信用卡支出的自然对数
#gender	性别(男=1)
#Age	年龄
#Income	年收入（万元）
#Ownrent	是否自有住房（有=1；无=0)
#Selfempl	是否自谋职业(1=yes, 0=no)
#dist_home_val	所住小区房屋均价(万元)
#dist_avg_income	当地人均收入
#high_avg	高出当地平均收入
#edu_class	教育等级：小学及以下开通=0，中学=1，本科=2，研究生=3
#—————————————————————————————————————————————————————————————————————————————————————————————————————————————###
creditcard_exp<-read.csv("data/creditcard_exp.csv")

head(creditcard_exp)
# Out:
#   id Acc avg_exp avg_exp_ln gender Age Income   Ownrent Selfempl dist_home_val
# 1 19 1   1217.03 7.104169   1      40  16.03515 1       1         99.93
# 2  5 1   1251.50 7.132098   1      32  15.84750 1       0         49.88
# 3 95 0        NA       NA   1      36   8.40000 0       0         88.61
# 4 86 1    856.57 6.752936   1      41  11.47285 1       0         16.10
# 5 50 1   1321.83 7.186772   1      28  13.40915 1       0        100.39
# 6 67 1    816.03 6.704451   1      41  10.03015 0       1        119.76
#   dist_avg_income age2 high_avg    edu_class
# 1 15.93279        1600  0.10236053 3
# 2 15.79632        1024  0.05118421 2
# 3  7.49000        1296  0.91000000 1
# 4 11.27563        1681  0.19721842 3
# 5 13.34647         784  0.06267632 2
# 6 10.33226        1681 -0.30211316 3

# %%
creditcard_exp<-na.omit(creditcard_exp)
attach(creditcard_exp)
creditcard_exp$gender<-as.factor(creditcard_exp$gender)

# %% [markdown]
# #    6.1 相关性分析

# %%
#散点图
plot(Income,avg_exp)
# Out:
# plot without title

# %%
#Correlation:"spearman","pearson" and "kendall",
cor.test(Income,avg_exp,method="pearson")
cor.test(Income,avg_exp,method="spearman")
# Out:
# 	Pearson's product-moment correlation
#
# data:  Income and avg_exp
# t = 7.5239, df = 68, p-value = 1.603e-10
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.5216538 0.7847069
# sample estimates:
#       cor
# 0.6740108
# 	Spearman's rank correlation rho
#
# data:  Income and avg_exp
# S = 16694, p-value < 2.2e-16
# alternative hypothesis: true rho is not equal to 0
# sample estimates:
#       rho
# 0.7079171

# %% [markdown]
# #   6.2 线性回归

# %%
#6.2.1简单线性回归
lm_s<-lm(avg_exp~Income)
coef(lm_s)
summary(lm_s)
# Out:
# (Intercept)      Income
#   258.04950    97.72858
# Call:
# lm(formula = avg_exp ~ Income)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -608.11 -215.85  -82.69  202.90  772.50
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   258.05     104.29   2.474   0.0158 *
# Income         97.73      12.99   7.524  1.6e-10 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 332.1 on 68 degrees of freedom
# Multiple R-squared:  0.4543,	Adjusted R-squared:  0.4463
# F-statistic: 56.61 on 1 and 68 DF,  p-value: 1.603e-10

# %%
#Predict
creditcard_exp$Pred1_avg_exp<-predict(lm_s)
creditcard_exp$Pred2_avg_exp<-fitted(lm_s)
creditcard_exp$resid_avg_exp<-resid(lm_s)

head(creditcard_exp)
# Out:
#   id Acc avg_exp avg_exp_ln gender Age Income   Ownrent Selfempl dist_home_val
# 1 19 1   1217.03 7.104169   1      40  16.03515 1       1         99.93
# 2  5 1   1251.50 7.132098   1      32  15.84750 1       0         49.88
# 4 86 1    856.57 6.752936   1      41  11.47285 1       0         16.10
# 5 50 1   1321.83 7.186772   1      28  13.40915 1       0        100.39
# 6 67 1    816.03 6.704451   1      41  10.03015 0       1        119.76
# 7 97 1   1151.15 7.048517   1      33  11.70575 1       0         38.90
#   dist_avg_income age2 high_avg    edu_class Pred1_avg_exp Pred2_avg_exp
# 1 15.93279        1600  0.10236053 3         1825.142      1825.142
# 2 15.79632        1024  0.05118421 2         1806.803      1806.803
# 4 11.27563        1681  0.19721842 3         1379.275      1379.275
# 5 13.34647         784  0.06267632 2         1568.507      1568.507
# 6 10.33226        1681 -0.30211316 3         1238.282      1238.282
# 7 11.52605        1089  0.17969737 3         1402.036      1402.036
#   resid_avg_exp
# 1 -608.1119
# 2 -555.3031
# 4 -522.7048
# 5 -246.6767
# 6 -422.2518
# 7 -250.8858

# %%
#6.2.2多元线性回归
lm_m<-lm(avg_exp~Age+Income+dist_home_val+dist_avg_income,data=creditcard_exp)
coef(lm_m)
summary(lm_m)
# Out:
#     (Intercept)             Age          Income   dist_home_val dist_avg_income
#      -32.007774        1.372317     -166.720391        1.532862      261.882708
# Call:
# lm(formula = avg_exp ~ Age + Income + dist_home_val + dist_avg_income,
#     data = creditcard_exp)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -504.07 -208.81  -40.92  129.69  681.02
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)      -32.008    186.874  -0.171  0.86454
# Age                1.372      5.605   0.245  0.80735
# Income          -166.720     87.607  -1.903  0.06147 .
# dist_home_val      1.533      1.057   1.450  0.15177
# dist_avg_income  261.883     87.807   2.982  0.00402 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 311.3 on 65 degrees of freedom
# Multiple R-squared:  0.5416,	Adjusted R-squared:  0.5134
# F-statistic:  19.2 on 4 and 65 DF,  p-value: 1.823e-10

# %%
#6.2.3多元线性回归的变量筛选
lm_m<-lm(avg_exp~Age+Income+dist_home_val+dist_avg_income,data=creditcard_exp)
summary(lm_m)
# Out:
# Call:
# lm(formula = avg_exp ~ Age + Income + dist_home_val + dist_avg_income,
#     data = creditcard_exp)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -504.07 -208.81  -40.92  129.69  681.02
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)      -32.008    186.874  -0.171  0.86454
# Age                1.372      5.605   0.245  0.80735
# Income          -166.720     87.607  -1.903  0.06147 .
# dist_home_val      1.533      1.057   1.450  0.15177
# dist_avg_income  261.883     87.807   2.982  0.00402 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 311.3 on 65 degrees of freedom
# Multiple R-squared:  0.5416,	Adjusted R-squared:  0.5134
# F-statistic:  19.2 on 4 and 65 DF,  p-value: 1.823e-10

# %%
#lm_ms<-step(lm_m,direction = "forward")
#step(lm_m,direction = "backward")
lm_ms<-step(lm_m,direction = "both")
summary(lm_ms)
# Out:
# Start:  AIC=808.53
# avg_exp ~ Age + Income + dist_home_val + dist_avg_income
#
#                   Df Sum of Sq     RSS    AIC
# - Age              1      5810 6306104 806.60
# <none>                         6300294 808.53
# - dist_home_val    1    203889 6504183 808.76
# - Income           1    351031 6651325 810.33
# - dist_avg_income  1    862197 7162491 815.51
#
# Step:  AIC=806.6
# avg_exp ~ Income + dist_home_val + dist_avg_income
#
#                   Df Sum of Sq     RSS    AIC
# <none>                         6306104 806.60
# - dist_home_val    1    205826 6511930 806.85
# - Income           1    345396 6651501 808.33
# + Age              1      5810 6300294 808.53
# - dist_avg_income  1    857139 7163244 813.52
# Call:
# lm(formula = avg_exp ~ Income + dist_home_val + dist_avg_income,
#     data = creditcard_exp)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -506.83 -210.79  -44.36  123.51  695.58
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)        2.351    122.525   0.019  0.98475
# Income          -164.438     86.487  -1.901  0.06163 .
# dist_home_val      1.540      1.049   1.468  0.14693
# dist_avg_income  260.752     87.058   2.995  0.00386 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 309.1 on 66 degrees of freedom
# Multiple R-squared:  0.5412,	Adjusted R-squared:  0.5203
# F-statistic: 25.95 on 3 and 66 DF,  p-value: 3.339e-11

# %% [markdown]
# #   6.3线性回归的诊断

# %%
#6.3.1残差分析
exp <- read.csv("data/creditcard_exp.csv")

head(exp)
# Out:
#   id Acc avg_exp avg_exp_ln gender Age Income   Ownrent Selfempl dist_home_val
# 1 19 1   1217.03 7.104169   1      40  16.03515 1       1         99.93
# 2  5 1   1251.50 7.132098   1      32  15.84750 1       0         49.88
# 3 95 0        NA       NA   1      36   8.40000 0       0         88.61
# 4 86 1    856.57 6.752936   1      41  11.47285 1       0         16.10
# 5 50 1   1321.83 7.186772   1      28  13.40915 1       0        100.39
# 6 67 1    816.03 6.704451   1      41  10.03015 0       1        119.76
#   dist_avg_income age2 high_avg    edu_class
# 1 15.93279        1600  0.10236053 3
# 2 15.79632        1024  0.05118421 2
# 3  7.49000        1296  0.91000000 1
# 4 11.27563        1681  0.19721842 3
# 5 13.34647         784  0.06267632 2
# 6 10.33226        1681 -0.30211316 3

# %%
exp <-na.omit(exp)
ana1<-lm(avg_exp~Income,data=exp)
summary(ana1)
# Out:
# Call:
# lm(formula = avg_exp ~ Income, data = exp)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -608.11 -215.85  -82.69  202.90  772.50
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   258.05     104.29   2.474   0.0158 *
# Income         97.73      12.99   7.524  1.6e-10 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 332.1 on 68 degrees of freedom
# Multiple R-squared:  0.4543,	Adjusted R-squared:  0.4463
# F-statistic: 56.61 on 1 and 68 DF,  p-value: 1.603e-10

# %%
exp$pred<-predict(ana1)
exp$res<-resid(ana1)

head(exp)
# Out:
#   id Acc avg_exp avg_exp_ln gender Age Income   Ownrent Selfempl dist_home_val
# 1 19 1   1217.03 7.104169   1      40  16.03515 1       1         99.93
# 2  5 1   1251.50 7.132098   1      32  15.84750 1       0         49.88
# 4 86 1    856.57 6.752936   1      41  11.47285 1       0         16.10
# 5 50 1   1321.83 7.186772   1      28  13.40915 1       0        100.39
# 6 67 1    816.03 6.704451   1      41  10.03015 0       1        119.76
# 7 97 1   1151.15 7.048517   1      33  11.70575 1       0         38.90
#   dist_avg_income age2 high_avg    edu_class pred     res
# 1 15.93279        1600  0.10236053 3         1825.142 -608.1119
# 2 15.79632        1024  0.05118421 2         1806.803 -555.3031
# 4 11.27563        1681  0.19721842 3         1379.275 -522.7048
# 5 13.34647         784  0.06267632 2         1568.507 -246.6767
# 6 10.33226        1681 -0.30211316 3         1238.282 -422.2518
# 7 11.52605        1089  0.17969737 3         1402.036 -250.8858

# %%
#Why use pred?
plot(exp$res~exp$pred)
# Out:
# plot without title

# %%
library(lmtest)
bptest(ana1)
# Out:
# Loading required package: zoo
#
# Attaching package: ‘zoo’
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
# 	studentized Breusch-Pagan test
#
# data:  ana1
# BP = 12.467, df = 1, p-value = 0.0004142

# %%
#遇到异方差情况,教科书上会介绍使用加权最小二乘法
#但是实际上最常用的是对被解释变量取对数
ana2<-lm(avg_exp_ln~Income,data=exp)
summary(ana2)
# Out:
# Call:
# lm(formula = avg_exp_ln ~ Income, data = exp)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.33858 -0.21063 -0.03193  0.24935  0.61969
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  6.05875    0.11634  52.077  < 2e-16 ***
# Income       0.09819    0.01449   6.776 3.58e-09 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.3705 on 68 degrees of freedom
# Multiple R-squared:  0.4031,	Adjusted R-squared:  0.3943
# F-statistic: 45.92 on 1 and 68 DF,  p-value: 3.578e-09

# %%
exp$pred<-predict(ana2)
exp$res<-resid(ana2)

# %%
#Why use pred?
plot(exp$res~exp$pred)
# Out:
# plot without title

# %%
bptest(ana2)
# Out:
# 	studentized Breusch-Pagan test
#
# data:  ana2
# BP = 0.60895, df = 1, p-value = 0.4352

# %%
#但是这样会使模型失去解释意义
exp$Income_ln<-log(exp$Income)
ana3<-lm(avg_exp_ln~Income_ln,data=exp)
summary(ana3)
# Out:
# Call:
# lm(formula = avg_exp_ln ~ Income_ln, data = exp)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.16234 -0.20937 -0.01781  0.27643  0.55853
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   5.0611     0.2217  22.833  < 2e-16 ***
# Income_ln     0.8932     0.1126   7.929 2.95e-11 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.3457 on 68 degrees of freedom
# Multiple R-squared:  0.4804,	Adjusted R-squared:  0.4728
# F-statistic: 62.87 on 1 and 68 DF,  p-value: 2.95e-11

# %%
exp$pred<-predict(ana3)
exp$res<-resid(ana3)

# %%
plot(exp$res~exp$pred)
# Out:
# plot without title

# %%
bptest(ana3)
# Out:
# 	studentized Breusch-Pagan test
#
# data:  ana3
# BP = 0.60574, df = 1, p-value = 0.4364

# %%
#寻找最优的模型
Rsq<-c(summary(ana1)$r.squared,summary(ana2)$r.squared,summary(ana3)$r.squared)
names(Rsq)<-c("EXP~Income","LN(EXP)~Income","LN(EXP)~LN(Income)")
Rsq
# Out:
#         EXP~Income     LN(EXP)~Income LN(EXP)~LN(Income)
#          0.4542906          0.4030856          0.4803928

# %%
#6.3.2强影响点分析
exp$res_t<-(exp$res-mean(exp$res))/sd(exp$res)
#Find outlier
exp$res_t[abs(exp$res_t)>2]

head(exp)
# Out:
# [1] -2.910292 -3.387317
#   id Acc avg_exp avg_exp_ln gender Age Income   Ownrent Selfempl dist_home_val
# 1 19 1   1217.03 7.104169   1      40  16.03515 1       1         99.93
# 2  5 1   1251.50 7.132098   1      32  15.84750 1       0         49.88
# 4 86 1    856.57 6.752936   1      41  11.47285 1       0         16.10
# 5 50 1   1321.83 7.186772   1      28  13.40915 1       0        100.39
# 6 67 1    816.03 6.704451   1      41  10.03015 0       1        119.76
# 7 97 1   1151.15 7.048517   1      33  11.70575 1       0         38.90
#   dist_avg_income age2 high_avg    edu_class pred     res        Income_ln
# 1 15.93279        1600  0.10236053 3         7.539420 -0.4352513 2.774783
# 2 15.79632        1024  0.05118421 2         7.528906 -0.3968081 2.763012
# 4 11.27563        1681  0.19721842 3         7.240390 -0.4874536 2.439983
# 5 13.34647         784  0.06267632 2         7.379682 -0.1929093 2.595937
# 6 10.33226        1681 -0.30211316 3         7.120360 -0.4159085 2.305596
# 7 11.52605        1089  0.17969737 3         7.258339 -0.2098226 2.460080
#   res_t
# 1 -1.2684217
# 2 -1.1563896
# 4 -1.4205513
# 5 -0.5621818
# 6 -1.2120525
# 7 -0.6114711

# %%
#Drop outlier
exp2<-subset(exp,abs(res_t)<=2,select=id:Income_ln)
ana4<-lm(avg_exp_ln~Income_ln,data=exp2)
exp2$pred<-predict(ana4)
exp2$res<-resid(ana4)
plot(exp2$res~exp2$pred)
# Out:
# plot without title

# %%
summary(ana4)
# Out:
# Call:
# lm(formula = avg_exp_ln ~ Income_ln, data = exp2)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.47280 -0.23028 -0.05378  0.22875  0.53152
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  5.31234    0.19249  27.598  < 2e-16 ***
# Income_ln    0.78040    0.09723   8.027 2.37e-11 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.2911 on 66 degrees of freedom
# Multiple R-squared:  0.494,	Adjusted R-squared:  0.4863
# F-statistic: 64.43 on 1 and 66 DF,  p-value: 2.372e-11

# %%
#6.3.3多重共线性分析
names(exp2)
exp2$dist_avg_income_ln<-log(exp2$dist_avg_income)
ana5<-lm(avg_exp~Income+Age+dist_home_val+dist_avg_income)
# Out:
#  [1] "id"              "Acc"             "avg_exp"         "avg_exp_ln"
#  [5] "gender"          "Age"             "Income"          "Ownrent"
#  [9] "Selfempl"        "dist_home_val"   "dist_avg_income" "age2"
# [13] "high_avg"        "edu_class"       "pred"            "res"
# [17] "Income_ln"

# %%
library(car)
vif(ana5)
# Out:
#          Income             Age   dist_home_val dist_avg_income
#       51.762376        1.161393        1.085603       51.753957

# %%
#The most easy way is to use step regression. However, it is not always work.
ana6<-step(ana5,direction = "both")
summary(ana6)
# Out:
# Start:  AIC=808.53
# avg_exp ~ Income + Age + dist_home_val + dist_avg_income
#
#                   Df Sum of Sq     RSS    AIC
# - Age              1      5810 6306104 806.60
# <none>                         6300294 808.53
# - dist_home_val    1    203889 6504183 808.76
# - Income           1    351031 6651325 810.33
# - dist_avg_income  1    862197 7162491 815.51
#
# Step:  AIC=806.6
# avg_exp ~ Income + dist_home_val + dist_avg_income
#
#                   Df Sum of Sq     RSS    AIC
# <none>                         6306104 806.60
# - dist_home_val    1    205826 6511930 806.85
# - Income           1    345396 6651501 808.33
# + Age              1      5810 6300294 808.53
# - dist_avg_income  1    857139 7163244 813.52
# Call:
# lm(formula = avg_exp ~ Income + dist_home_val + dist_avg_income)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -506.83 -210.79  -44.36  123.51  695.58
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)        2.351    122.525   0.019  0.98475
# Income          -164.438     86.487  -1.901  0.06163 .
# dist_home_val      1.540      1.049   1.468  0.14693
# dist_avg_income  260.752     87.058   2.995  0.00386 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 309.1 on 66 degrees of freedom
# Multiple R-squared:  0.5412,	Adjusted R-squared:  0.5203
# F-statistic: 25.95 on 3 and 66 DF,  p-value: 3.339e-11

# %%
vif(ana6)
# Out:
#          Income   dist_home_val dist_avg_income
#       51.176222        1.084867       51.610836

# %%
ana7<-lm(avg_exp~dist_home_val+dist_avg_income+high_avg)
vif(ana7)
# Out:
#   dist_home_val dist_avg_income        high_avg
#        1.084867        1.076029        1.011873

# %% [markdown]
# #   6.4 正则算法

# %%
#6.4.1岭回归
#在R中实现岭回归的包有很多，比如glmnet和MASS，本节使用两种方法分别做演示

library(MASS)

# %%
lmr<-lm.ridge(avg_exp~.,data=creditcard_exp[,c(3,6,7,10,11)],lambda=seq(0,10,1))
plot(lmr)
# Out:
# plot without title

# %%
select(lmr)
# Out:
# modified HKB estimator is 0.215325
# modified L-W estimator is 1.823165
# smallest value of GCV  at 0

# %%
names(creditcard_exp)
x <- as.matrix(creditcard_exp[,c(6,7,10,11) ])
y <- as.matrix(creditcard_exp[,c(3) ])

head(x)
head(y)
# Out:
#  [1] "id"              "Acc"             "avg_exp"         "avg_exp_ln"
#  [5] "gender"          "Age"             "Income"          "Ownrent"
#  [9] "Selfempl"        "dist_home_val"   "dist_avg_income" "age2"
# [13] "high_avg"        "edu_class"       "Pred1_avg_exp"   "Pred2_avg_exp"
# [17] "resid_avg_exp"
#   Age Income   dist_home_val dist_avg_income
# 1 40  16.03515  99.93        15.93279
# 2 32  15.84750  49.88        15.79632
# 4 41  11.47285  16.10        11.27563
# 5 28  13.40915 100.39        13.34647
# 6 41  10.03015 119.76        10.33226
# 7 33  11.70575  38.90        11.52605
#      [,1]
# [1,] 1217.03
# [2,] 1251.50
# [3,]  856.57
# [4,] 1321.83
# [5,]  816.03
# [6,] 1151.15

# %%
library(glmnet)

# %%
# alpha = 0表示岭回归
r1 <- glmnet(x = x, y = y, family = "gaussian", alpha = 0)
plot(r1, xvar = "lambda",label=TRUE)
# Out:
# plot without title

# %%
r1.cv <- cv.glmnet(x = x, y = y, family = "gaussian", alpha = 0, nfold = 10)
plot(r1.cv)
# Out:
# plot without title

# %%
# 选择lambda的原则
#lambda.min:value of lambda that gives minimum cvm(交叉验证误差最小)
r1.cv$lambda.min
r1.min <- glmnet(x = x, y = y, family = "gaussian", alpha = 0, lambda = r1.cv$lambda.min)
coef(r1.min)
#lambda.1se:largest value of lambda such that error is within 1 standard error of the minimum.
#r1.cv$lambda.1se
#r1.1se <- glmnet(x = x, y = y, family = "gaussian", alpha = 0, lambda = r1.cv$lambda.1se)
#coef(r1.1se)
# Out:
# [1] 34.28289
# 5 x 1 sparse Matrix of class "dgCMatrix"
#                          s0
# (Intercept)     109.4054036
# Age               0.9499978
# Income           21.5395485
# dist_home_val     1.7327241
# dist_avg_income  69.3984372

# %%
#6.4.2 LASSO算法
# alpha = 1表示lasso
r2 <- glmnet(x = x, y = y, family = "gaussian", alpha = 1)
plot(r2, xvar = "lambda")
# Out:
# plot without title

# %%
r2.cv <- cv.glmnet(x = x, y = y, family = "gaussian", alpha = 1, nfold = 10)
plot(r2.cv)
# Out:
# plot without title

# %%
# 选择lambda的原则
r2.cv$lambda.min
r2.min <- glmnet(x = x, y = y, family = "gaussian", alpha = 1, lambda = r2.cv$lambda.min)
coef(r2.min)
# Out:
# [1] 0.1384006
# 5 x 1 sparse Matrix of class "dgCMatrix"
#                          s0
# (Intercept)      -26.836324
# Age                1.310687
# Income          -159.787167
# dist_home_val      1.539034
# dist_avg_income  254.988860

# %%
r2.cv$lambda.1se
r2.1se <- glmnet(x = x, y = y, family = "gaussian", alpha = 1, lambda = 50)
coef(r2.1se)
# Out:
# [1] 102.288
# 5 x 1 sparse Matrix of class "dgCMatrix"
#                          s0
# (Intercept)     262.8371233
# Age               .
# Income            .
# dist_home_val     0.6496158
# dist_avg_income  83.9919708
